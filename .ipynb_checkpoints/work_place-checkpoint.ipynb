# %%
import torch
import torch.nn.functional as F
from torch import nn
from torch.nn import BatchNorm1d, ReLU, Linear, Sequential
import numpy as np
from torch_geometric.data import Data, InMemoryDataset, download_url
from torch_geometric.nn import GCNConv, global_mean_pool, GATConv, GINConv, global_add_pool
import os
from torch_geometric.loader import DataLoader
import networkx as nx
from sklearn.preprocessing import OrdinalEncoder, OneHotEncoder
from torch_geometric.transforms import NormalizeFeatures

from src.data.peptides_functional import PeptidesFunctionalDataset

from src.models.models import *

from sklearn.metrics import average_precision_score

# %%
# %load_ext autoreload

# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
dataset = PeptidesFunctionalDataset("datasets")
idx_lst = np.random.choice([i for i in range(len(dataset))], size=500, replace=False)
dataset = dataset[idx_lst]
# Out:
# Downloading https://www.dropbox.com/s/ol2v01usvaxbsr8/peptide_multi_class_dataset.csv.gz?dl=1
# Downloading https://www.dropbox.com/s/j4zcnx2eipuo0xz/splits_random_stratified_peptide.pickle?dl=1
# Processing...
# Converting SMILES strings into graphs...
#  42%|████▏     | 6474/15535 [00:20<00:28, 314.35it/s][16:32:45] WARNING: not removing hydrogen atom without neighbors
# [16:32:45] WARNING: not removing hydrogen atom without neighbors
# 100%|██████████| 15535/15535 [00:49<00:00, 312.18it/s]
# Saving...
# Done!

# %%
Y = []
for data in dataset:
    Y.append(data.y.tolist()[0])
    
new_data = [list(y) for y in set([tuple(x) for x in Y])]

n_class = len(new_data)

# %%
input_channels = dataset.num_node_features
hidden_channels = 32
output_channels = n_class

# %%
data
# Out:
# Data(edge_index=[2, 282], edge_attr=[282, 3], x=[138, 9], y=[1, 10])

# %%
one_hot = []
for y in Y:
    to_add = [0 for idx in range(n_class)]
    to_add[new_data.index(y)] = 1
    one_hot.append(to_add)
    continue

# %%
data_lst = []
for idx in range(len(dataset)):
    data = dataset[idx]
    data.y = torch.FloatTensor([one_hot[idx]])
    data_lst.append(data)

# %%
d = data_lst[0]
g1 = nx.Graph(d.edge_index.T.tolist())
nx.draw(g1, node_size=6, width=0.5)
old_edgs = list(g1.edges)

# %%
nx.average_shortest_path_length(g1)
# Out:
# 26.97608695652174

# %%
d = data_lst[0]
g1 = nx.Graph(d.edge_index.T.tolist())
color_lst = []
for edg in list(g1.edges):
    if edg in old_edgs:
        color_lst.append("black")
    else:
        color_lst.append("red")
nx.draw(g1, node_size=6, width=0.5, edge_color=color_lst)

# %%
nx.average_shortest_path_length(g1)
# Out:
# 3.084371327849589

# %%
for data in data_lst:
    edgelist = data.edge_index.T.numpy()
    new_edgelist = []

    while len(new_edgelist) <= len(edgelist): 
        n = data.x.shape[0]
        a = np.random.choice(n)
        b = np.random.choice(n)
        if a == b:
            continue

        new_edgelist.append([a, b])

    edgelist = torch.LongTensor(np.concatenate([edgelist, new_edgelist]).T)
    data.edge_index = edgelist

# %%
model = GCN(16, input_channels, output_channels)

# %%
train_set, val_set = torch.utils.data.random_split(data_lst, [int(len(dataset)*0.8), len(dataset) - int(len(dataset)*0.8)])
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
criterion = torch.nn.CrossEntropyLoss()
train_loader = DataLoader(train_set, batch_size=10, shuffle=True)
test_loader = DataLoader(val_set, batch_size=10, shuffle=False)

# %%
def train():
    model.train()

    for data in train_loader:
        # Iterate in batches over the training dataset.
        out = model(data.x.float(), data.edge_index, data.batch)  # Perform a single forward pass.
        loss = criterion(out, data.y)  # Compute the loss.
        loss.backward()  # Derive gradients.
        optimizer.step()  # Update parameters based on gradients.
        optimizer.zero_grad()  # Clear gradients.

def test(loader):
    model.eval()
    loss_total = 0
    for data in loader:  # Iterate in batches over the training/test dataset.
        out = model(data.x.float(), data.edge_index, data.batch)  
        loss = average_precision_score(data.y.numpy()[0], out.detach().numpy()[0])
        loss_total += loss
    return loss_total / len(loader.dataset)  # Derive ratio of correct predictions.

# %%
for epoch in range(1, 100):
    train()
    train_acc = test(train_loader)
    test_acc = test(test_loader)
    print(f'Epoch: {epoch:03d}, Train Loss: {train_acc:.4f}, Test Loss: {test_acc:.4f}\n')
# Out:
# Epoch: 001, Train Loss: 0.0272, Test Loss: 0.0416
#
# Epoch: 002, Train Loss: 0.0337, Test Loss: 0.0417
#
# Epoch: 003, Train Loss: 0.0407, Test Loss: 0.0417
#
# Epoch: 004, Train Loss: 0.0389, Test Loss: 0.0417
#
# Epoch: 005, Train Loss: 0.0433, Test Loss: 0.0402
#
# Epoch: 006, Train Loss: 0.0525, Test Loss: 0.0402
#
# Epoch: 007, Train Loss: 0.0331, Test Loss: 0.0402
#
# Epoch: 008, Train Loss: 0.0396, Test Loss: 0.0419
#
# Epoch: 009, Train Loss: 0.0387, Test Loss: 0.0402
#
# Epoch: 010, Train Loss: 0.0406, Test Loss: 0.0402
#
# Epoch: 011, Train Loss: 0.0391, Test Loss: 0.0402
#
# Epoch: 012, Train Loss: 0.0372, Test Loss: 0.0402
#
# Epoch: 013, Train Loss: 0.0320, Test Loss: 0.0402
#
# Epoch: 014, Train Loss: 0.0449, Test Loss: 0.0402
#
# Epoch: 015, Train Loss: 0.0241, Test Loss: 0.0402
#
# Epoch: 016, Train Loss: 0.0360, Test Loss: 0.0402
#
# Epoch: 017, Train Loss: 0.0370, Test Loss: 0.0402
#
# Epoch: 018, Train Loss: 0.0368, Test Loss: 0.0402
#
# Epoch: 019, Train Loss: 0.0351, Test Loss: 0.0402
#
# Epoch: 020, Train Loss: 0.0389, Test Loss: 0.0402
#
# Epoch: 021, Train Loss: 0.0365, Test Loss: 0.0402
#
# Epoch: 022, Train Loss: 0.0347, Test Loss: 0.0402
#
# Epoch: 023, Train Loss: 0.0406, Test Loss: 0.0402
#
# Epoch: 024, Train Loss: 0.0352, Test Loss: 0.0402
#
# Epoch: 025, Train Loss: 0.0431, Test Loss: 0.0402
#
# Epoch: 026, Train Loss: 0.0310, Test Loss: 0.0402
#
# Epoch: 027, Train Loss: 0.0345, Test Loss: 0.0402
#
# Epoch: 028, Train Loss: 0.0381, Test Loss: 0.0402
#
# Epoch: 029, Train Loss: 0.0417, Test Loss: 0.0402
#
# Epoch: 030, Train Loss: 0.0411, Test Loss: 0.0402
#
# Epoch: 031, Train Loss: 0.0403, Test Loss: 0.0402
#
# Epoch: 032, Train Loss: 0.0252, Test Loss: 0.0402
#
# Epoch: 033, Train Loss: 0.0346, Test Loss: 0.0402
#
# Epoch: 034, Train Loss: 0.0317, Test Loss: 0.0402
#
# Epoch: 035, Train Loss: 0.0407, Test Loss: 0.0402
#
# Epoch: 036, Train Loss: 0.0390, Test Loss: 0.0419
#
# Epoch: 037, Train Loss: 0.0398, Test Loss: 0.0402
#
# Epoch: 038, Train Loss: 0.0436, Test Loss: 0.0402
#
# Epoch: 039, Train Loss: 0.0443, Test Loss: 0.0402
#
# Epoch: 040, Train Loss: 0.0404, Test Loss: 0.0402
#
# Epoch: 041, Train Loss: 0.0426, Test Loss: 0.0402
#
# Epoch: 042, Train Loss: 0.0479, Test Loss: 0.0419
#
# Epoch: 043, Train Loss: 0.0427, Test Loss: 0.0402
#
# Epoch: 044, Train Loss: 0.0402, Test Loss: 0.0402
#
# Epoch: 045, Train Loss: 0.0363, Test Loss: 0.0402
#
# Epoch: 046, Train Loss: 0.0388, Test Loss: 0.0402
#
# Epoch: 047, Train Loss: 0.0361, Test Loss: 0.0419
#
# Epoch: 048, Train Loss: 0.0426, Test Loss: 0.0402
#
# Epoch: 049, Train Loss: 0.0441, Test Loss: 0.0419
#
# Epoch: 050, Train Loss: 0.0401, Test Loss: 0.0402
#
# Epoch: 051, Train Loss: 0.0408, Test Loss: 0.0402
#
# Epoch: 052, Train Loss: 0.0359, Test Loss: 0.0402
#
# Epoch: 053, Train Loss: 0.0355, Test Loss: 0.0402
#
# Epoch: 054, Train Loss: 0.0338, Test Loss: 0.0402
#
# Epoch: 055, Train Loss: 0.0417, Test Loss: 0.0402
#
# Epoch: 056, Train Loss: 0.0309, Test Loss: 0.0402
#
# Epoch: 057, Train Loss: 0.0370, Test Loss: 0.0402
#
# Epoch: 058, Train Loss: 0.0340, Test Loss: 0.0402
#
# Epoch: 059, Train Loss: 0.0389, Test Loss: 0.0402
#
# Epoch: 060, Train Loss: 0.0375, Test Loss: 0.0402
#
# Epoch: 061, Train Loss: 0.0404, Test Loss: 0.0402
#
# Epoch: 062, Train Loss: 0.0406, Test Loss: 0.0402
#
# Epoch: 063, Train Loss: 0.0379, Test Loss: 0.0402
#
# Epoch: 064, Train Loss: 0.0470, Test Loss: 0.0402
#
# Epoch: 065, Train Loss: 0.0409, Test Loss: 0.0402
#
# Epoch: 066, Train Loss: 0.0361, Test Loss: 0.0402
#
# Epoch: 067, Train Loss: 0.0391, Test Loss: 0.0402
#
# Epoch: 068, Train Loss: 0.0379, Test Loss: 0.0402
#
# Epoch: 069, Train Loss: 0.0398, Test Loss: 0.0402
#
# Epoch: 070, Train Loss: 0.0383, Test Loss: 0.0402
#
# Epoch: 071, Train Loss: 0.0400, Test Loss: 0.0402
#
# Epoch: 072, Train Loss: 0.0395, Test Loss: 0.0402
#
# Epoch: 073, Train Loss: 0.0424, Test Loss: 0.0402
#
# Epoch: 074, Train Loss: 0.0411, Test Loss: 0.0402
#
# Epoch: 075, Train Loss: 0.0395, Test Loss: 0.0402
#
# Epoch: 076, Train Loss: 0.0358, Test Loss: 0.0402
#
# Epoch: 077, Train Loss: 0.0287, Test Loss: 0.0402
#
# Epoch: 078, Train Loss: 0.0396, Test Loss: 0.0402
#
# Epoch: 079, Train Loss: 0.0371, Test Loss: 0.0402
#
# Epoch: 080, Train Loss: 0.0371, Test Loss: 0.0402
#
# Epoch: 081, Train Loss: 0.0454, Test Loss: 0.0402
#
# Epoch: 082, Train Loss: 0.0427, Test Loss: 0.0402
#
# Epoch: 083, Train Loss: 0.0433, Test Loss: 0.0402
#
# Epoch: 084, Train Loss: 0.0439, Test Loss: 0.0402
#
# Epoch: 085, Train Loss: 0.0304, Test Loss: 0.0402
#
# Epoch: 086, Train Loss: 0.0396, Test Loss: 0.0402
#
# Epoch: 087, Train Loss: 0.0374, Test Loss: 0.0402
#
# Epoch: 088, Train Loss: 0.0385, Test Loss: 0.0402
#
# Epoch: 089, Train Loss: 0.0346, Test Loss: 0.0402
#
# Epoch: 090, Train Loss: 0.0434, Test Loss: 0.0402
#
# Epoch: 091, Train Loss: 0.0353, Test Loss: 0.0402
#
# Epoch: 092, Train Loss: 0.0345, Test Loss: 0.0402
#
# Epoch: 093, Train Loss: 0.0386, Test Loss: 0.0402
#
# Epoch: 094, Train Loss: 0.0384, Test Loss: 0.0402
#
# Epoch: 095, Train Loss: 0.0384, Test Loss: 0.0402
#
# Epoch: 096, Train Loss: 0.0348, Test Loss: 0.0402
#
# Epoch: 097, Train Loss: 0.0343, Test Loss: 0.0402
#
# Epoch: 098, Train Loss: 0.0325, Test Loss: 0.0402
#
# Epoch: 099, Train Loss: 0.0417, Test Loss: 0.0402

# %%
from src.data.test import load_dataset
from src.models.models import *
import json

# %%
with open('config/test-params.json') as fh:
    test_params = json.load(fh)

# %%
data_lst, input_channels, output_channels = load_dataset(**test_params)
# Out:
# start testing loading the PyG dataset
# Dataset loaded and shuffled!

# %%
from src.process.algorithms import random_shortcuts

# %%
new_data_lst = random_shortcuts(data_lst)

# %%
model = GCN(input_channels, 16, output_channels)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
criterion = torch.nn.CrossEntropyLoss()
train_loader = DataLoader(train_set, batch_size=10, shuffle=True)
test_loader = DataLoader(val_set, batch_size=10, shuffle=False)

# %%
from src.utils.utils import *

# %%
run(model, data_list, 0.8, criterion, optimizer, 10)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipykernel_3326587/539378781.py in <module>
# ----> 1 run(model, train_loader, test_loader, criterion, optimizer, 50)
#
# ~/nn/LR-GNN/src/utils/utils.py in run(model, train_loader, test_loader, criterion, optimizer, epoch)
#      38
#      39     for epoch in range(1, epoch):
# ---> 40         train()
#      41         train_acc = test(train_loader)
#      42         test_acc = test(test_loader)
#
# ~/nn/LR-GNN/src/utils/utils.py in train()
#      21         for data in train_loader:
#      22             # Iterate in batches over the training dataset.
# ---> 23             out = model(data.x.float(), data.edge_index, data.batch)  # Perform a single forward pass.
#      24             loss = criterion(out, data.y)  # Compute the loss.
#      25             loss.backward()  # Derive gradients.
#
# ~/anaconda3/lib/python3.9/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1128         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130             return forward_call(*input, **kwargs)
#    1131         # Do not call functions when jit is used
#    1132         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/nn/LR-GNN/src/models/models.py in forward(self, x, edge_index, batch)
#      54
#      55         x = F.dropout(x, p=0.6, training=self.training)
# ---> 56         x = self.conv1(x, edge_index)
#      57         x = F.elu(x)
#      58         x = F.dropout(x, p=0.6, training=self.training)
#
# ~/anaconda3/lib/python3.9/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1128         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130             return forward_call(*input, **kwargs)
#    1131         # Do not call functions when jit is used
#    1132         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/anaconda3/lib/python3.9/site-packages/torch_geometric/nn/conv/gcn_conv.py in forward(self, x, edge_index, edge_weight)
#     192                     edge_index = cache
#     193
# --> 194         x = self.lin(x)
#     195
#     196         # propagate_type: (x: Tensor, edge_weight: OptTensor)
#
# ~/anaconda3/lib/python3.9/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1128         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130             return forward_call(*input, **kwargs)
#    1131         # Do not call functions when jit is used
#    1132         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/anaconda3/lib/python3.9/site-packages/torch_geometric/nn/dense/linear.py in forward(self, x)
#     116             x (Tensor): The features.
#     117         """
# --> 118         return F.linear(x, self.weight, self.bias)
#     119
#     120     @torch.no_grad()
#
# RuntimeError: mat1 and mat2 shapes cannot be multiplied (1125x7 and 9x16)

# %%
def run(epoch):
    
    def train():
        model.train()

        for data in train_loader:
            # Iterate in batches over the training dataset.
            out = model(data.x.float(), data.edge_index, data.batch)  # Perform a single forward pass.
            loss = criterion(out, data.y)  # Compute the loss.
            loss.backward()  # Derive gradients.
            optimizer.step()  # Update parameters based on gradients.
            optimizer.zero_grad()  # Clear gradients.

    def test(loader):
        model.eval()
        loss_total = 0
        for data in loader:  # Iterate in batches over the training/test dataset.
            out = model(data.x.float(), data.edge_index, data.batch)  
            loss = average_precision_score(data.y.numpy()[0], out.detach().numpy()[0])
            loss_total += loss
        return loss_total / len(loader.dataset)  # Derive ratio of correct predictions.
    
    
    for epoch in range(1, epoch):
        train()
        train_acc = test(train_loader)
        test_acc = test(test_loader)
        print(f'Epoch: {epoch:03d}, Train Loss: {train_acc:.4f}, Test Loss: {test_acc:.4f}\n')

# %%
run(100)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_3326587/1804830013.py in <module>
# ----> 1 run(100)
#
# /tmp/ipykernel_3326587/2475169913.py in run(epoch)
#      24     for epoch in range(1, epoch):
#      25         train()
# ---> 26         train_acc = test(train_loader)
#      27         test_acc = test(test_loader)
#      28         print(f'Epoch: {epoch:03d}, Train Loss: {train_acc:.4f}, Test Loss: {test_acc:.4f}\n')
#
# /tmp/ipykernel_3326587/2475169913.py in test(loader)
#      17         for data in loader:  # Iterate in batches over the training/test dataset.
#      18             out = model(data.x.float(), data.edge_index, data.batch)
# ---> 19             loss = average_precision_score(data.y.numpy()[0], out.detach().numpy()[0])
#      20             loss_total += loss
#      21         return loss_total / len(loader.dataset)  # Derive ratio of correct predictions.
#
# ~/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_ranking.py in average_precision_score(y_true, y_score, average, pos_label, sample_weight)
#     222     average_precision = partial(_binary_uninterpolated_average_precision,
#     223                                 pos_label=pos_label)
# --> 224     return _average_binary_score(average_precision, y_true, y_score,
#     225                                  average, sample_weight=sample_weight)
#     226
#
# ~/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_base.py in _average_binary_score(binary_metric, y_true, y_score, average, sample_weight)
#      75
#      76     if y_type == "binary":
# ---> 77         return binary_metric(y_true, y_score, sample_weight=sample_weight)
#      78
#      79     check_consistent_length(y_true, y_score, sample_weight)
#
# ~/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_ranking.py in _binary_uninterpolated_average_precision(y_true, y_score, pos_label, sample_weight)
#     199     def _binary_uninterpolated_average_precision(
#     200             y_true, y_score, pos_label=1, sample_weight=None):
# --> 201         precision, recall, _ = precision_recall_curve(
#     202             y_true, y_score, pos_label=pos_label, sample_weight=sample_weight)
#     203         # Return the step function integral
#
# ~/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_ranking.py in precision_recall_curve(y_true, probas_pred, pos_label, sample_weight)
#     809
#     810     """
# --> 811     fps, tps, thresholds = _binary_clf_curve(y_true, probas_pred,
#     812                                              pos_label=pos_label,
#     813                                              sample_weight=sample_weight)
#
# ~/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_ranking.py in _binary_clf_curve(y_true, y_score, pos_label, sample_weight)
#     691         raise ValueError("{0} format is not supported".format(y_type))
#     692
# --> 693     check_consistent_length(y_true, y_score, sample_weight)
#     694     y_true = column_or_1d(y_true)
#     695     y_score = column_or_1d(y_score)
#
# ~/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py in check_consistent_length(*arrays)
#     314     """
#     315
# --> 316     lengths = [_num_samples(X) for X in arrays if X is not None]
#     317     uniques = np.unique(lengths)
#     318     if len(uniques) > 1:
#
# ~/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py in <listcomp>(.0)
#     314     """
#     315
# --> 316     lengths = [_num_samples(X) for X in arrays if X is not None]
#     317     uniques = np.unique(lengths)
#     318     if len(uniques) > 1:
#
# ~/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py in _num_samples(x)
#     257     if hasattr(x, 'shape') and x.shape is not None:
#     258         if len(x.shape) == 0:
# --> 259             raise TypeError("Singleton array %r cannot be considered"
#     260                             " a valid collection." % x)
#     261         # Check that shape is returning an integer or default to len
#
# TypeError: Singleton array 1 cannot be considered a valid collection.
